# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !ls
# Out:
# sample_data

# %%
# !ls drive
# Out:
# ls: cannot access 'drive': No such file or directory

# %%
# !ls /content
# Out:
# sample_data

# %%
# !ls /content/drive
# Out:
# ls: cannot access '/content/drive': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
# !ls /content/drive
# Out:
# MyDrive

# %%
# !ls /content/drive/MyDrive
# Out:
# '14200322005_SAGARIKA BANDYOPADHYAY_DAA.pdf'
# '14200322007_SAGARIKA BANDYOPADHYAY_CA_CA2 (1).pdf'
# '14200322007_SAGARIKA BANDYOPADHYAY_CA_CA2 (2).pdf'
# '14200322007_SAGARIKA BANDYOPADHYAY_CA_CA2.pdf'
# '14200322007_Sagarika Bandyopadhyay_CA_.pdf'
# '14200322007_SAGARIKA BANDYOPADHYAY_DC (1).pdf'
# '14200322007_SAGARIKA BANDYOPADHYAY_DC_CA2.pdf'
# '14200322007_SAGARIKA BANDYOPADHYAY_DC.pdf'
#  14200322007_Sagarika_Bandyopadhyay_DSP.pdf
# '14200322007_Sagarika Bandyopadhyay_EMT_CA2.pdf'
# '14200322007_Sagarika Bandyopadhyay_Nano.pdf'
# '14200322007_Sagarika Bandyopadhyay_NE_CA2.pdf'
#  14200322007_Sagarika_Bandyopadhyay.pdf
#  14200322007_SagarikaBandyopadhyay.pdf
#  14200322007__SagarikaBandyopadhyay.pdf
# '14200322007_Sagarika Bandyopadhyay_TR.gsheet'
# '14200322007_Sagarika Bandyopadhyay_VLSI.pdf'
# '14th July.pdf'
#  1589019497659..jpg
#  1.pdf
# '1st Sep CW.pdf'
#  20221106_221127.jpg
#  20240903_111025.jpg
#  203-Bengali.rar
# '26th May CW.pdf'
#  5_6100524702030104314.pdf
#  5_6100524702030104315.pdf
# '5th Sem form.pdf'
#  97802288-4594-48f5-b848-b0e62e275898.gdoc
#  97802288-4594-48f5-b848-b0e62e275898.pdf
# 'Aadhar card Sagarika.pdf'
# 'Admit card Term 2 .pdf'
# 'ANIKET JANA CHEMISTRY FRONT PAGE REAL111PDF.pdf'
# 'application CIF.pdf'
# 'April II (b).pdf'
#  AUTOMATIC_OPTIMIZE_CLASS_ROUTINE_GENERATION.pdf
# 'baba '
# 'Bits and tits'
#  CAT_EMOTIONS
#  Classroom
# 'CodeyoungOfferLetter (1).pdf'
#  CodeyoungOfferLetter.pdf
# 'Colab Notebooks'
# 'College '
#  Consent_letter_SBH2024.pdf
# 'Contact Information (1).gform'
# 'Contact Information (2).gform'
# 'Contact Information (File responses)'
# 'Contact Information.gform'
# 'Contact Information (Responses).gsheet'
# 'Copy of DEMOSTRATION.jpg'
# 'CV_Sagarika_ECE (1).pdf'
#  CV_Sagarika_ECE.pdf
# 'DBMS certificate.pdf'
# 'DocScanner 30 May 2022 9-16 pm.pdf'
# 'DSC_0600 (1).JPG'
#  DSC_0600.JPG
#  ECE
#  ECE2-14200322007.pdf
#  ECE3-14200322007.pdf
# 'EVENT: ঋদ্ধি (RIDDHI) (File responses)'
# 'EVENT: ঋদ্ধি (RIDDHI).gform'
# 'EVENT: ঋদ্ধি (RIDDHI) (Responses).gsheet'
# 'exam phy.pdf'
#  Excelerate
#  FB_IMG_1706036979735.jpg
# 'FORMULA 📖📒'
# 'GDSC ASSIGNMENT.zip'
#  Sagarika_Bandyopadhyay_CV.pdf
#  SagarikaBandyopadhyay_EC601_ECE.pdf
#  Sagarika_Bandyopadhyay.jpg
# 'Sagarika Bandyopadhyay - mcq periodic classification.docx.pdf'
#  Sagarika_CFL-2.pdf
# 'Sagarika_ch_1&2- Mock Test.pdf'
# 'Sagarika~Ch7,10,11~Mock test.pdf'
# 'Sagarika chem mock test (1) 22nd April.pdf'
# 'Sagarika chem mock test 21st oct.pdf'
#  Sagarika_chemobj_term1.pdf
# 'Sagarika chem subjective 1.pdf'
# 'Sagarika MAR.xls'
# 'sagarika_XII chem CFL1.pdf'
# 'Sagarika_XII_chem_mocktest_Ch1&2.pdf'
# 'School XI'
#  Screenshot_20210626-112840_BHIM.jpg
#  Screenshot_20250405-221003_GPay.jpg
# 'SHAROD SHIROPA ID  10.png'
# 'SHAROD SHIROPA ID  1.png'
# 'SHAROD SHIROPA ID  2.png'
# 'SHAROD SHIROPA ID  3.png'
# 'SHAROD SHIROPA ID  4.png'
# 'SHAROD SHIROPA ID  5.png'
# 'SHAROD SHIROPA ID  6.png'
# 'SHAROD SHIROPA ID  7.png'
# 'SHAROD SHIROPA ID  8.png'
# 'SHAROD SHIROPA ID  9.png'
# 'SHAROD SHIROPA ID CARDS'
# 'Signature (2).jpg'
# '(SIH1604) PROBLEM STATEMENT _240901_202011.pdf'
#  SmartSelect_20210706-193113_Gallery.jpg
#  SmartSelect_20220109-143725_Gallery.jpg
#  SmartSelect_20230223-130640_GPay.jpg
#  SmartSelect_20230223-131241_Gallery.jpg
#  SmartSelect_20230508-213703_GPay.jpg
#  SmartSelect_20240104-212807_Instagram.jpg
#  SmartSelect_20240104-212822_Instagram.jpg
#  SmartSelect_20240104-212847_Instagram.jpg
#  SmartSelect_20240104-213000_Instagram.jpg
#  SmartSelect_20240104-213022_Instagram.jpg
#  SmartSelect_20240307-235230_GPay.jpg
#  SmartSelect_20240328-134407_GPay.jpg
#  SmartSelect_20240510-221144_GPay.jpg
#  SmartSelect_20240514-101453_GPay.jpg
#  SmartSelect_20240926-210203_GPay.jpg
#  SmartSelect_20241007-105417_GPay.jpg
#  SmartSelect_20250209-025755_GPay.jpg
#  SmartSelect_20250915-165131_Gallery.jpg
#  SmartSelect_20250915-170935_GPay.jpg
#  Solution_Assignment-2_2022-23.docx
# 'Team Jarvis Recruitment Drive.gform'
# 'T-Shirt Sign Up.gform'
# 'T-Shirt Sign Up (Responses).gsheet'
# 'Untitled document.gdoc'
# 'Untitled presentation (10).gslides'
# 'Untitled presentation (11).gslides'
# 'Untitled presentation (12).gslides'
# 'Untitled presentation (13).gslides'
# 'Untitled presentation (14).gslides'
# 'Untitled presentation (15).gslides'
# 'Untitled presentation (16).gslides'
# 'Untitled presentation (17).gslides'
# 'Untitled presentation (18).gslides'
# 'Untitled presentation (19).gslides'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation (20).gslides'
# 'Untitled presentation (21).gslides'
# 'Untitled presentation (2).gslides'
# 'Untitled presentation (3).gslides'
# 'Untitled presentation (4).gslides'
# 'Untitled presentation (5).gslides'
# 'Untitled presentation (6).gslides'
# 'Untitled presentation (7).gslides'
# 'Untitled presentation (8).gslides'
# 'Untitled presentation (9).gslides'
# 'Untitled presentation.gslides'
#  Video
# 'Voter Card.pdf'
# 'Wapp docs'
# 'WhatsApp Image 2024-10-28 at 9.38.28 PM.jpeg'
# 'WhatsApp Image 2024-10-28 at 9.54.16 PM.jpeg'

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW
# Out:
# ls: cannot access '/content/drive/MyDrive/CAT_ROBOFLOW': No such file or directory

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW/train
# Out:
# ls: cannot access '/content/drive/MyDrive/CAT_ROBOFLOW/train': No such file or directory

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW/valid
# Out:
# ls: cannot access '/content/drive/MyDrive/CAT_ROBOFLOW/valid': No such file or directory

# %%
TRAIN_DIR = "/content/drive/MyDrive/CAT_ROBOFLOW/train"
VAL_DIR   = "/content/drive/MyDrive/CAT_ROBOFLOW/valid"

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

IMG_SIZE = 224
BATCH_SIZE = 32

train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(IMG_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

val_transforms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transforms)
val_dataset   = datasets.ImageFolder(VAL_DIR, transform=val_transforms)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

print("Classes:", train_dataset.classes)
print("Number of classes:", len(train_dataset.classes))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1824689185.py in <cell line: 0>()
# ----> 1 train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transforms)
#       2 val_dataset   = datasets.ImageFolder(VAL_DIR, transform=val_transforms)
#       3
#       4 train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
#       5 val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     147     ) -> None:
#     148         super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149         classes, class_to_idx = self.find_classes(self.root)
#     150         samples = self.make_dataset(
#     151             self.root,
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     232             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233         """
# --> 234         return find_classes(directory)
#     235
#     236     def __getitem__(self, index: int) -> tuple[Any, Any]:
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/CAT_ROBOFLOW/train'

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# %%
from torchvision import models
import torch.nn as nn

model = models.resnet50(
    weights=models.ResNet50_Weights.IMAGENET1K_V1
)

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
num_classes = len(train_dataset.classes)

model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(512, num_classes)
)

# %%
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()

# %%
import torch.optim as optim

optimizer = optim.AdamW(
    model.fc.parameters(),
    lr=3e-4,
    weight_decay=1e-4
)

# %%
def train_one_epoch(model, loader):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    for images, labels in loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / len(loader), correct / total

# %%
def validate(model, loader):
    model.eval()
    correct = 0
    total = 0
    val_loss = 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return val_loss / len(loader), correct / total

# %%
EPOCHS = 10
best_val_acc = 0

for epoch in range(EPOCHS):
    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_resnet_head.pth")

# %%
for param in model.parameters():
    param.requires_grad = True

# %%
optimizer = optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-5
)

# %%
EPOCHS_FINE = 15

for epoch in range(EPOCHS_FINE):
    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"[Fine-Tune] Epoch {epoch+1}/{EPOCHS_FINE}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_resnet_finetuned.pth")

# %%
EPOCHS = 20
best_val_acc = 0

for epoch in range(EPOCHS):
    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_resnet_head.pth")

# %%
EPOCHS = 5
best_val_acc = 0

for epoch in range(EPOCHS):
    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_resnet_head.pth")

# %%
for param in model.parameters():
    param.requires_grad = True

# %%
optimizer = optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-5
)

# %%
model.load_state_dict(torch.load("best_resnet_head.pth"))

# %%
model = model.to(device)

# %%
for param in model.parameters():
    param.requires_grad = True

# %%
import torch.optim as optim

optimizer = optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-5
)

# %%
EPOCHS_FINE = 10
best_val_acc = 0

for epoch in range(EPOCHS_FINE):
    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"[Fine-Tune] Epoch {epoch+1}/{EPOCHS_FINE}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(
            model.state_dict(),
            "/content/drive/MyDrive/CAT_ROBOFLOW/models/best_resnet_finetuned.pth"
        )

# %%
# !mkdir -p /content/drive/MyDrive/CAT_ROBOFLOW/models

# %%
EPOCHS_FINE = 10
best_val_acc = 0

for epoch in range(EPOCHS_FINE):
    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"[Fine-Tune] Epoch {epoch+1}/{EPOCHS_FINE}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(
            model.state_dict(),
            "/content/drive/MyDrive/CAT_ROBOFLOW/models/best_resnet_finetuned.pth"
        )

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW/models

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Recreate ResNet50 with same classifier
num_classes = len(train_dataset.classes)

model = models.resnet50(
    weights=models.ResNet50_Weights.IMAGENET1K_V1
)

model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(512, num_classes)
)

# %%
MODEL_PATH = "/content/drive/MyDrive/CAT_ROBOFLOW/models/best_resnet_finetuned.pth"

model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model = model.to(device)
model.eval()

# %%
infer_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
IMAGE_PATH = "/content/drive/MyDrive/test_image.jpg"

# %%
# !ls /content/drive/MyDrive

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW/valid

# %%
IMAGE_PATH = "/content/drive/MyDrive/CAT_ROBOFLOW/valid/Happy/img_023.jpg"

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW/valid

# %%
# !ls /content/drive/MyDrive/CAT_ROBOFLOW/valid/Happy | head

# %%
IMAGE_PATH = "/content/drive/MyDrive/CAT_ROBOFLOW/valid/Happy/10_h_jpeg.rf.1ab362f340524f4490188b73e9551357.jpg"

# %%
from PIL import Image

image = Image.open(IMAGE_PATH).convert("RGB")

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis("off")

# %%
IMAGE_PATH = "/content/drive/MyDrive/CAT_ROBOFLOW/valid/Happy/11_h_jpeg.rf.b43139316c03dc5d6b39a2888bebe618.jpg"

# %%
from PIL import Image

image = Image.open(IMAGE_PATH).convert("RGB")

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis("off")

# %%
image_tensor = infer_transform(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image_tensor)
    probs = torch.softmax(outputs, dim=1)
    pred_idx = torch.argmax(probs, dim=1).item()

pred_class = train_dataset.classes[pred_idx]
confidence = probs[0][pred_idx].item()

print("Predicted class:", pred_class)
print("Confidence:", round(confidence * 100, 2), "%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2683464781.py in <cell line: 0>()
# ----> 1 image_tensor = infer_transform(image).unsqueeze(0).to(device)
#       2
#       3 with torch.no_grad():
#       4     outputs = model(image_tensor)
#       5     probs = torch.softmax(outputs, dim=1)
#
# NameError: name 'infer_transform' is not defined
